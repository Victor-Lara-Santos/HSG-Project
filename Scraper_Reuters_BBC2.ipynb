# %%
import requests
from bs4 import BeautifulSoup

#url to be scrapped
url = 'https://www.reuters.com/news/archive/marketsNews'
result = requests.get(url)
content = result.content
soup = BeautifulSoup(content, 'html.parser')

#finding the headlines
soup.find_all('h3', {'class':'story-title'})
titles = []
for title in soup.find_all('h3', {'class':'story-title'}):
    titles.append(title.string.strip())

#subtracting number of titles so all future arrays have the same number of instances
titles = titles[:-3]

#getting the summary and preventing duplicates
first_lines = []
try:
    for first_line in soup.find_all('p'):
        first_lines.append(first_line.string.strip())
except:
    pass

#subtracting number of summaries so all future arrays have the same number of instances
first_lines = first_lines[:-2]

#getting urlsand preventing duplicates
url_links = []
import re

for tags in soup.find_all('a'):
    if re.search('article', tags['href']):
        url_links.append(tags['href'])
#subtracting number of urls so all future arrays have the same number of instances
url_links = url_links[:-6]
final_urls = []
for url in url_links:
    if url not in final_urls:
        final_urls.append(url)
import pandas as pd

reuters_word_headlines = pd.DataFrame({'title':titles, 'headline content':first_lines, 'link url':final_urls})
reuters_word_headlines=\
reuters_word_headlines.loc[:,('title', 'headline content', 'link url')]
reuters_word_headlines['link url'] =\
'www.reuters.com' + reuters_word_headlines['link url']
print(reuters_word_headlines)

# creates header and emulates browser
headers = {'User-agent': 'Mozilla/5.0'}

# make the request to the website in order to grab HTML
request = requests.get('https://www.bbc.com/news', headers=headers)
html = request.content

soup = BeautifulSoup(html, 'html.parser')

def bbc_news_scraper(keyword):
    news_list2 = []
# Finds all headers on the website
    for h in soup.findAll('h3', class_='gs-c-promo-heading__title'):
        news_title2 = h.contents[0].lower()

#avoids duplicates and ads from being added to the list
        if news_title2 not in news_list2:
            if 'bbc' not in news_title2:
                news_list2.append(news_title2)
# Divides BBC Headings from Reuters headings
    print(f'\n--------- BBC ---------')
    print(*news_list2, sep = '\n')
    
#in order to make the same for other websites, it is only necessary to change the html class and the heading to the specific format of the target site

#bbc_headline_scraper from indently in github was used as an inspiration and tutorial
#Reuters scrapper inspired from Seungjun-Data-Science tutorial on github

print(bbc_news_scraper('1'))
# Out:
#                                                title  \
# 0  UPDATE 14-Bankman-Fried leaves Bahamas after c...
# 1  PRECIOUS-Gold steady as investors eye economic...
# 2  Plane with Bankman-Fried departs Bahamas after...
# 3  Sam Bankman-Fried boarded plane in Bahamas, se...
# 4  Motorcade arrives at Bahamas airport after Ban...
# 5               DIARY-Top Economic Events to Feb. 22
# 6  UPDATE 3-Micron sets 10% job cuts in 2023 due ...
# 7         MORNING BID-Will Indonesia follow the Fed?
# 8  Republican senators propose overhaul of Federa...
# 9  US STOCKS-Wall Street ends up with help from N...
#
#                                     headline content  \
# 0  FTX founder Sam Bankman-Fried\nleft the Bahama...
# 1  Gold prices were little changed\nduring early ...
# 2  A plane that a source said\nwas carrying Sam B...
# 3  FTX founder Sam Bankman-Fried on Wednesday eve...
# 4  A police motorcade\nwas seen arriving at an ai...
# 5  Today in Washington\n-------------------------...
# 6  Chipmaker Micron Technology Inc\non Wednesday ...
# 7  A look at the day ahead in Asian\nmarkets from...
# 8  Seven Republican U.S.\nsenators on Wednesday a...
# 9  Wall Street's three main stock\nindexes closed...
#
#                                             link url
# 0  www.reuters.com/article/fintech-crypto-ftx-ext...
# 1  www.reuters.com/article/global-precious/precio...
# 2  www.reuters.com/article/fintech-crypto-ftx-ext...
# 3  www.reuters.com/article/fintech-crypto-ftx-ext...
# 4  www.reuters.com/article/fintech-crypto-ftx-ext...
# 5  www.reuters.com/article/diary-top-econ/diary-t...
# 6  www.reuters.com/article/micron-tech-results/up...
# 7  www.reuters.com/article/global-markets-view-as...
# 8  www.reuters.com/article/usa-fed-reform/republi...
# 9  www.reuters.com/article/usa-stocks/us-stocks-w...
#
# --------- BBC ---------
# zelensky tells congress ukraine will never surrender
# putin says russia not to blame for ukraine war
# china's hospitals seem to be filling up - who
# israel's most right-wing government agreed
# nepal jail to free serial killer the serpent
# mead wins sports personality of the year
# powerful us storm disrupts holiday travel
# body found in undercarriage of uk plane
# pele's cancer has advanced, says hospital
# family of lockerbie suspect say he is innocent
# eight canadian teen girls charged with killing man
# trump business losses sharply reduced his tax bill
# ex-ftx boss agrees to be extradited to us - lawyer
# gambia coup attempt foiled - government
# in pictures: zelensky's momentous day in washington
# iran protesters 'too scared to go to hospital'
# ros atkins on... china’s covid surge
# listen: president zelensky's warm welcome in washington
# japan store donki mascot survives axe after uproar
# reynolds and mcelhenney awarded freedom of city
# zelensky follows in churchill's footsteps with wartime address
# fleeing china for us - by trekking through a jungle
# 'everyone i know is getting a fever' - covid hits china
# what zelensky and biden want from this washington visit
# the man who survived the 'nazi typist's' concentration camp
# afghanistan: 'not a country but a cage for women'
# this is what el paso looks like amid border crisis
# how to make a low-carbon roast
# why love and sex are changing
# is santa claus buried in ireland?
# the first royal celebrity
# the rodent with biological superpowers
# the workplace buzzwords of 2022
# the world's fried chicken capital?
# None
